# %% [markdown]
# # Running the Aspect_Extraction and Sentiment_Analysis Notebooks Files

# %%
# %run "Aspect_Extraction.ipynb"
# %run "Sentiment_Analysis.ipynb"

# %% [markdown]
# # Import libraries

# %%
import spacy
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji
import os
import json
from deep_translator import GoogleTranslator
from textblob import TextBlob 
from nltk.tokenize import sent_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.sentiment.vader import SentimentIntensityAnalyzer


# Check if NLTK resources are available; if not, download them
if not nltk.data.find('corpora/stopwords.zip'):
    nltk.download('stopwords')

if not nltk.data.find('tokenizers/punkt'):
    nltk.download('punkt')

if not nltk.data.find('sentiment/vader_lexicon.zip'):
    nltk.download('vader_lexicon')
    
# nltk.download('stopwords')
nlp = spacy.load("en_core_web_sm")  # Load the spaCy English model
# nltk.download('punkt')  # Download the Punkt tokenizer models
# nltk.download('vader_lexicon')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
# Set the option to display full column width and all rows
pd.set_option("display.max_colwidth",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# ## Translate text into English

# %%
def translate(text):
    translator = GoogleTranslator(source='auto', target='en')
    return translator.translate(text)

text1 = "बढ़िया खाना था"
print(translate(text1))
# Out:
# it was great food

# %% [markdown]
# ## Handling Emojies

# %%
positive_emojis = """😄😀😁😆😂🤣😊🙂😎😉😍🥰😘😋😛😝😜🤪🤩🥳🥰❤️👍👌🤟🍔🍕🍣🍰🍹🍷🍺
                    🍦🍯🥞🍟🍩🥼🎉🎊🥳🍚🍘🍥🥠🥮🍢🍡🍧🍨🍦🥧🧁🍰🎂🍮🍭🍬🍫🍿🍩🍪🌰🥜
                    🍯🍻🥂🍷🍾😀😃😄😆😅🥲\😊😇🙂😀😃😄😁😅😆😂🙂😊🤒👏"""

    
negative_emojis = """😔😞😢😭😤😠😡🤬😩😫🥺😖😣😠😤😷🤒🤕😐😶😒😏🙁🥶😨😱😰😳🥵😳😵
                     🤯🤐🤮🥴🤢👎😈👿💔😩😔😞😢😭"""


# add space between word and emoji
def handle_emoji_helper(text):
    i = 0
    lst = list(text)
    for word in text:
        if word !=" " and (word in positive_emojis or word in negative_emojis):
            lst.insert(i," ")
        i+=1
    return "".join(lst)

def handle_emoji(sentence):
    sentence = handle_emoji_helper(sentence)
    words = sentence.split()
    converted_sentence = []
    for word in words:
        if word in positive_emojis:
            converted_sentence.append("good") # Don't change ( one word sentences will be removed in
        elif word in negative_emojis:                                     #      preprocessing )
            converted_sentence.append("bad")
        else:
            converted_sentence.append(word)
    return " ".join(converted_sentence)

# # Example usage:
# input_sentence = "😀"
# input_sentence = "बढ़िया खाना था😀"
# converted = handle_emoji(input_sentence)
# print(converted)

# %% [markdown]
# # Data PreProcessing

# %%
# Data Cleaning
def clean_text(text):
    if text is not None:
        # Lowercase the text
        text = text.lower()
        # Remove special characters and punctuation
        text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
    return text

# Text preprocessing functions
def preprocess_text(text, state = 0):
    text = handle_emoji(text)
    if state == 1:
        text = translate(text)
    if text is not None:
        if state == 0:
            text = clean_text(text)
            text = ' '.join([lemmatizer.lemmatize(word) for word in text.split() if word.lower() not in stop_words and len(word)>2])
            text = text if len(text.split()) > 1 else ""    
        
    return text

# %% [markdown]
# ### Function to tokenize text into sentences

# %%
def split_complex_sentence(text):
    doc = nlp(text) # Parse the text
    simpler_sentences = []
    temp_sentence = []
    
    # Iterate through the parsed tokens
    for token in doc:
        # Check for coordinating conjunctions (e.g., "and," "but") to split the sentence
        if token.dep_ == "cc":
            if temp_sentence:
                simpler_sentences.append(" ".join(temp_sentence))
            temp_sentence = []
        else:
            temp_sentence.append(token.text)

    if temp_sentence:
        simpler_sentences.append(" ".join(temp_sentence))
    
    sentences = []
    for sentence in simpler_sentences:
        sentences.append(sent_tokenize(sentence))

    flattened_sentences = [sentence for sublist in sentences for sentence in sublist]
    return flattened_sentences

# text  = The service at the restaurant was excellent. The food was also good but atmosphere were not good."
# simplified_sentences = split_complex_sentence(text)
# for sentence in simplified_sentences:
#     print(sentence)

# %% [markdown]
# # Load Unlabeled dataset [ Define filename if you are running this file directly ]

# %%
# Define filename if you are running this file directly
# e.g. "aa_sample_dataset/First_Restaurant_Review_dataset.csv"
# input_df = pd.read_csv(filename)
input_df = pd.read_csv("aa_sample_dataset/First_Restaurant_Review_dataset.csv")

# %%
input_df.head()
# Out:
#                                                                                     Review
# 0                                                                 Wow... Loved this place.
# 1                                                                       Crust is not good.
# 2                                                Not tasty and the texture was just nasty.
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# 4                              The selection on the menu was great and so were the prices.

# %% [markdown]
# ### Add index to the DataFrame

# %%
input_df['idx'] = range(10, (len(input_df) + 1)*10, 10)

# %% [markdown]
# ### Converting every Review text into simple sentences and forming new dataframe as discussed earlier

# %%
new_df_list = []  # Create a list to store DataFrames

for i, (idx, text) in enumerate(zip(input_df['idx'], input_df['Review'])):
    sentences = split_complex_sentence(text)  # split_complex_sentence defined in the start
    sentences_df = pd.DataFrame({'Review': sentences, 'idx': range(idx, idx + len(sentences))})
    new_df_list.append(sentences_df)

new_df = pd.concat(new_df_list, ignore_index=True)  # Concatenate all DataFrames at once

# %% [markdown]
# ### Replacing old dataset by new dataset

# %%
input_df = new_df.copy()
# input_df.head() # print dataset head

# %% [markdown]
# ### Preprocessing Review to create new column cleaned_review

# %%
from tqdm import tqdm

tqdm.pandas()

# df_temp['y'] = df_temp.ratings.progress_map(label)
input_df['Cleaned_Review'] = input_df['Review'].progress_map(preprocess_text)
input_df.head()
# Out:
# 100%|██████████████████████████████████████| 1580/1580 [00:01<00:00, 923.86it/s]
#                          Review  idx Cleaned_Review
# 0                       Wow ...   10
# 1            Loved this place .   11    loved place
# 2           Crust is not good .   20     crust good
# 3                     Not tasty   30
# 4  the texture was just nasty .   31  texture nasty

# %% [markdown]
# ### Deleting rows where cleaned_review column is empty

# %%
input_df = input_df[input_df['Cleaned_Review'] != ""]
# input_df

# %% [markdown]
# ### Drop the custom index and reset to the default integer-based index

# %%
input_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Rearrange the column order

# %%
# Create a list of column names in the desired order
desired_order = ['idx', 'Review', 'Cleaned_Review']

# Rearrange the columns
input_df = input_df[desired_order]

# %% [markdown]
# # Opinion Target (Aspect) Extraction

# %%
# An empty list for obtaining the extracted aspects from sentences.  
aspects =[]

sentences = input_df['Review']
sentences = sentences.astype(str)
# Performing Aspect Extraction 
for sen in sentences: 
    important = nlp(sen)  # Fix the variable name 'sen'
    descriptive_item = '' 
    target = '' 
    temp_target = ''
    for token in important: 
        if token.dep_ == 'nsubj' and token.pos_ == 'NOUN': 
            target = token.text   
        if target =='' and token.pos_ == 'NOUN': 
            temp_target = token.text 

    if target == '': target = temp_target
    aspects.append(target)

# %%
# creating a dataset having sinlge column = Opinion_Target
new_column_df = pd.DataFrame({'Opinion_Target' : aspects})

# Concatenate new column ( Opinion_Target ) into input_df dataset horizontally (along columns)
input_df = pd.concat([input_df, new_column_df], axis=1)
# input_df.head()

# %% [markdown]
# # Predict the Opinion_Category

# %%
# Vectorize the Opinion_Target using the  tfidf_vectorizer
sample_tfidf = tfidf_vectorizer1.transform(input_df['Opinion_Target'])

# Predicting the Opinion_Category 
predicted_aspect_category = SVM_opinion_category_classifier.predict(sample_tfidf)

# adding column Opinion_Category
input_df['Opinion_Category'] = predicted_aspect_category

# unique values of Opinion_Category 
input_df['Opinion_Category'].value_counts()
# Out:
# Opinion_Category
# FOOD#QUALITY                1011
# SERVICE#GENERAL              112
# RESTAURANT#GENERAL            92
# AMBIENCE#GENERAL              36
# FOOD#STYLE_OPTIONS            22
# RESTAURANT#MISCELLANEOUS       7
# DRINKS#QUALITY                 7
# LOCATION#GENERAL               2
# DRINKS#STYLE_OPTIONS           1
# Name: count, dtype: int64

# %%
input_df.head()
# Out:
#    idx  \
# 0   11
# 1   20
# 2   31
# 3   40
# 4   50
#
#                                                                       Review  \
# 0                                                         Loved this place .
# 1                                                        Crust is not good .
# 2                                               the texture was just nasty .
# 3  Stopped by during the late May bank holiday off Rick Steve recommendation
# 4                                        The selection on the menu was great
#
#                                             Cleaned_Review  Opinion_Target  \
# 0                                              loved place           place
# 1                                               crust good           Crust
# 2                                            texture nasty         texture
# 3  stopped late may bank holiday rick steve recommendation  recommendation
# 4                                     selection menu great       selection
#
#      Opinion_Category
# 0  RESTAURANT#GENERAL
# 1        FOOD#QUALITY
# 2        FOOD#QUALITY
# 3        FOOD#QUALITY
# 4        FOOD#QUALITY

# %% [markdown]
# ### Handle missing values of Opinion_Target Column

# %%
# Opinion_Target = "" and Opinion_Category = "FOOD#QUALITY" then food of before # is Opinion_Target
# Assumption just  to handle missing value
def missing_value_handler(df):
    return df['Opinion_Category'].split('#')[0].lower() if pd.isna(df['Opinion_Target']) else df['Opinion_Target']

input_df['Opinion_Target'] = input_df.apply(missing_value_handler, axis = 1)

# %%
# input_df

# %% [markdown]
# # Predict the Opinion_Polarity

# %%
# Vectorize the sample sentence using the same tfidf_vectorizer
# Note:- this function is defined in sentiment_analysis.ipynb notebook
sample_tfidf = tfidf_vectorizer.transform(input_df['Cleaned_Review'])

# Predict the sentiment for the sample sentence
Predicted_Opinion_Polarity = svm_sentiment_classifier.predict(sample_tfidf)

# adding new column Opinion_Polarity in dataset
input_df['Opinion_Polarity'] = Predicted_Opinion_Polarity

# %%
# print dataset
input_df
# Out:
#         idx  \
# 0        11
# 1        20
# 2        31
# 3        40
# 4        50
# 5        60
# 6        61
# 7        70
# 8        80
# 9        81
# 10       90
# 11      100
# 12      110
# 13      120
# 14      130
# 15      140
# 16      150
# 17      160
# 18      170
# 19      180
# 20      190
# 21      210
# 22      220
# 23      230
# 24      240
# 25      241
# 26      260
# 27      270
# 28      280
# 29      281
# 30      290
# 31      300
# 32      310
# 33      311
# 34      320
# 35      330
# 36      331
# 37      340
# 38      342
# 39      350
# 40      360
# 41      370
# 42      371
# 43      380
# 44      390
# 45      400
# 46      410
# 47      420
# 48      430
# 49      431
# 50      440
# 51      441
# 52      450
# 53      460
# 54      461
# 55      470
# 56      480
# 57      490
# 58      500
# 59      502
# 60      510
# 61      512
# 62      520
# 63      530
# 64      540
# 65      541
# 66      550
# 67      560
# 68      561
# 69      570
# 70      580
# 71      581
# 72      590
# 73      600
# 74      610
# 75      620
# 76      630
# 77      640
# 78      650
# 79      660
# 80      661
# 81      662
# 82      670
# 83      680
# 84      681
# 85      690
# 86      691
# 87      692
# 88      700
# 89      710
# 90      712
# 91      713
# 92      720
# 93      730
# 94      740
# 95      750
# 96      751
# 97      760
# 98      770
# 99      780
# 100     781
# 101     790
# 102     791
# 103     800
# 104     810
# 105     821
# 106     822
# 107     831
# 108     850
# 109     860
# 110     861
# 111     870
# 112     880
# 113     890
# 114     900
# 115     910
# 116     920
# 117     930
# 118     940
# 119     950
# 120     980
# 121    1000
# 122    1010
# 123    1011
# 124    1012
# 125    1013
# 126    1020
# 127    1021
# 128    1030
# 129    1040
# 130    1041
# 131    1050
# 132    1060
# 133    1061
# 134    1070
# 135    1072
# 136    1080
# 137    1081
# 138    1090
# 139    1100
# 140    1110
# 141    1120
# 142    1121
# 143    1130
# 144    1140
# 145    1150
# 146    1170
# 147    1180
# 148    1190
# 149    1200
# 150    1201
# 151    1210
# 152    1220
# 153    1221
# 154    1230
# 155    1231
# 156    1240
# 157    1241
# 158    1242
# 159    1250
# 160    1251
# 161    1260
# 162    1270
# 163    1271
# 164    1280
# 165    1290
# 166    1300
# 167    1310
# 168    1320
# 169    1330
# 170    1331
# 171    1340
# 172    1350
# 173    1360
# 174    1370
# 175    1380
# 176    1390
# 177    1391
# 178    1400
# 179    1401
# 180    1420
# 181    1422
# 182    1431
# 183    1432
# 184    1440
# 185    1450
# 186    1451
# 187    1460
# 188    1461
# 189    1470
# 190    1471
# 191    1480
# 192    1490
# 193    1500
# 194    1511
# 195    1513
# 196    1520
# 197    1530
# 198    1540
# 199    1550
# 200    1560
# 201    1561
# 202    1570
# 203    1571
# 204    1572
# 205    1580
# 206    1581
# 207    1590
# 208    1600
# 209    1610
# 210    1611
# 211    1620
# 212    1630
# 213    1631
# 214    1640
# 215    1650
# 216    1651
# 217    1670
# 218    1680
# 219    1690
# 220    1700
# 221    1710
# 222    1711
# 223    1712
# 224    1720
# 225    1730
# 226    1740
# 227    1750
# 228    1751
# 229    1760
# 230    1761
# 231    1770
# 232    1780
# 233    1781
# 234    1790
# 235    1791
# 236    1800
# 237    1810
# 238    1811
# 239    1820
# 240    1830
# 241    1840
# 242    1850
# 243    1851
# 244    1860
# 245    1870
# 246    1871
# 247    1880
# 248    1890
# 249    1900
# 250    1902
# 251    1910
# 252    1920
# 253    1930
# 254    1940
# 255    1941
# 256    1942
# 257    1950
# 258    1960
# 259    1970
# 260    1980
# 261    1981
# 262    1990
# 263    2000
# 264    2010
# 265    2011
# 266    2020
# 267    2030
# 268    2040
# 269    2050
# 270    2060
# 271    2070
# 272    2072
# 273    2080
# 274    2090
# 275    2100
# 276    2110
# 277    2111
# 278    2120
# 279    2130
# 280    2150
# 281    2160
# 282    2180
# 283    2191
# 284    2200
# 285    2210
# 286    2220
# 287    2230
# 288    2232
# 289    2240
# 290    2241
# 291    2250
# 292    2260
# 293    2270
# 294    2280
# 295    2290
# 296    2300
# 297    2310
# 298    2320
# 299    2330
# 300    2340
# 301    2341
# 302    2350
# 303    2352
# 304    2360
# 305    2370
# 306    2371
# 307    2380
# 308    2381
# 309    2390
# 310    2400
# 311    2410
# 312    2420
# 313    2430
# 314    2440
# 315    2450
# 316    2460
# 317    2470
# 318    2480
# 319    2490
# 320    2500
# 321    2501
# 322    2510
# 323    2520
# 324    2530
# 325    2540
# 326    2550
# 327    2561
# 328    2570
# 329    2580
# 330    2590
# 331    2601
# 332    2610
# 333    2620
# 334    2621
# 335    2630
# 336    2640
# 337    2641
# 338    2650
# 339    2651
# 340    2670
# 341    2680
# 342    2681
# 343    2690
# 344    2700
# 345    2710
# 346    2720
# 347    2740
# 348    2750
# 349    2751
# 350    2760
# 351    2761
# 352    2770
# 353    2771
# 354    2780
# 355    2781
# 356    2800
# 357    2801
# 358    2810
# 359    2820
# 360    2840
# 361    2850
# 362    2860
# 363    2870
# 364    2880
# 365    2890
# 366    2900
# 367    2902
# 368    2910
# 369    2911
# 370    2920
# 371    2930
# 372    2931
# 373    2940
# 374    2950
# 375    2960
# 376    2970
# 377    2980
# 378    2990
# 379    3000
# 380    3001
# 381    3010
# 382    3011
# 383    3012
# 384    3020
# 385    3030
# 386    3031
# 387    3032
# 388    3040
# 389    3050
# 390    3060
# 391    3070
# 392    3080
# 393    3081
# 394    3090
# 395    3100
# 396    3110
# 397    3120
# 398    3130
# 399    3140
# 400    3150
# 401    3151
# 402    3160
# 403    3170
# 404    3171
# 405    3172
# 406    3173
# 407    3180
# 408    3181
# 409    3190
# 410    3191
# 411    3200
# 412    3210
# 413    3220
# 414    3230
# 415    3231
# 416    3240
# 417    3241
# 418    3250
# 419    3260
# 420    3261
# 421    3280
# 422    3281
# 423    3282
# 424    3290
# 425    3291
# 426    3301
# 427    3302
# 428    3310
# 429    3311
# 430    3320
# 431    3321
# 432    3330
# 433    3331
# 434    3340
# 435    3350
# 436    3360
# 437    3370
# 438    3371
# 439    3381
# 440    3382
# 441    3390
# 442    3400
# 443    3410
# 444    3420
# 445    3430
# 446    3431
# 447    3440
# 448    3450
# 449    3460
# 450    3470
# 451    3480
# 452    3481
# 453    3490
# 454    3500
# 455    3501
# 456    3510
# 457    3511
# 458    3530
# 459    3540
# 460    3560
# 461    3561
# 462    3570
# 463    3580
# 464    3581
# 465    3590
# 466    3600
# 467    3610
# 468    3611
# 469    3620
# 470    3630
# 471    3640
# 472    3641
# 473    3650
# 474    3660
# 475    3670
# 476    3680
# 477    3690
# 478    3700
# 479    3710
# 480    3711
# 481    3720
# 482    3730
# 483    3731
# 484    3740
# 485    3751
# 486    3760
# 487    3770
# 488    3771
# 489    3780
# 490    3791
# 491    3800
# 492    3820
# 493    3830
# 494    3831
# 495    3840
# 496    3850
# 497    3851
# 498    3860
# 499    3870
# 500    3880
# 501    3900
# 502    3910
# 503    3911
# 504    3920
# 505    3930
# 506    3931
# 507    3940
# 508    3941
# 509    3950
# 510    3951
# 511    3952
# 512    3960
# 513    3961
# 514    3970
# 515    3980
# 516    3990
# 517    3991
# 518    4000
# 519    4001
# 520    4010
# 521    4020
# 522    4030
# 523    4040
# 524    4041
# 525    4050
# 526    4051
# 527    4060
# 528    4070
# 529    4080
# 530    4081
# 531    4090
# 532    4100
# 533    4110
# 534    4111
# 535    4120
# 536    4130
# 537    4140
# 538    4150
# 539    4151
# 540    4160
# 541    4170
# 542    4180
# 543    4190
# 544    4191
# 545    4200
# 546    4201
# 547    4202
# 548    4210
# 549    4220
# 550    4221
# 551    4230
# 552    4240
# 553    4242
# 554    4270
# 555    4271
# 556    4280
# 557    4290
# 558    4300
# 559    4310
# 560    4320
# 561    4330
# 562    4340
# 563    4341
# 564    4342
# 565    4350
# 566    4360
# 567    4370
# 568    4380
# 569    4381
# 570    4390
# 571    4400
# 572    4410
# 573    4420
# 574    4430
# 575    4440
# 576    4450
# 577    4460
# 578    4461
# 579    4480
# 580    4490
# 581    4491
# 582    4500
# 583    4501
# 584    4510
# 585    4520
# 586    4530
# 587    4531
# 588    4532
# 589    4533
# 590    4550
# 591    4560
# 592    4570
# 593    4571
# 594    4580
# 595    4590
# 596    4600
# 597    4610
# 598    4620
# 599    4621
# 600    4631
# 601    4640
# 602    4650
# 603    4660
# 604    4661
# 605    4670
# 606    4680
# 607    4681
# 608    4690
# 609    4701
# 610    4710
# 611    4720
# 612    4730
# 613    4740
# 614    4750
# 615    4751
# 616    4760
# 617    4770
# 618    4780
# 619    4781
# 620    4790
# 621    4791
# 622    4810
# 623    4811
# 624    4820
# 625    4821
# 626    4830
# 627    4831
# 628    4832
# 629    4840
# 630    4851
# 631    4860
# 632    4870
# 633    4871
# 634    4880
# 635    4890
# 636    4891
# 637    4910
# 638    4920
# 639    4930
# 640    4931
# 641    4940
# 642    4950
# 643    4960
# 644    4970
# 645    4971
# 646    4980
# 647    4990
# 648    4991
# 649    5000
# 650    5010
# 651    5011
# 652    5020
# 653    5030
# 654    5040
# 655    5051
# 656    5060
# 657    5070
# 658    5080
# 659    5090
# 660    5100
# 661    5110
# 662    5111
# 663    5112
# 664    5120
# 665    5130
# 666    5140
# 667    5150
# 668    5160
# 669    5170
# 670    5180
# 671    5190
# 672    5200
# 673    5210
# 674    5230
# 675    5240
# 676    5241
# 677    5250
# 678    5260
# 679    5270
# 680    5280
# 681    5281
# 682    5290
# 683    5291
# 684    5300
# 685    5310
# 686    5320
# 687    5330
# 688    5340
# 689    5341
# 690    5342
# 691    5350
# 692    5360
# 693    5370
# 694    5380
# 695    5390
# 696    5401
# 697    5410
# 698    5420
# 699    5421
# 700    5430
# 701    5440
# 702    5450
# 703    5460
# 704    5461
# 705    5470
# 706    5471
# 707    5480
# 708    5490
# 709    5501
# 710    5502
# 711    5510
# 712    5520
# 713    5530
# 714    5540
# 715    5550
# 716    5560
# 717    5570
# 718    5580
# 719    5590
# 720    5600
# 721    5610
# 722    5611
# 723    5620
# 724    5630
# 725    5640
# 726    5641
# 727    5650
# 728    5651
# 729    5660
# 730    5661
# 731    5670
# 732    5671
# 733    5680
# 734    5690
# 735    5700
# 736    5711
# 737    5720
# 738    5740
# 739    5750
# 740    5751
# 741    5760
# 742    5770
# 743    5771
# 744    5780
# 745    5781
# 746    5790
# 747    5800
# 748    5801
# 749    5810
# 750    5830
# 751    5840
# 752    5850
# 753    5860
# 754    5861
# 755    5862
# 756    5870
# 757    5880
# 758    5890
# 759    5900
# 760    5910
# 761    5920
# 762    5921
# 763    5930
# 764    5940
# 765    5941
# 766    5950
# 767    5960
# 768    5970
# 769    5980
# 770    5990
# 771    5991
# 772    6000
# 773    6011
# 774    6020
# 775    6021
# 776    6030
# 777    6040
# 778    6050
# 779    6060
# 780    6080
# 781    6090
# 782    6091
# 783    6112
# 784    6120
# 785    6130
# 786    6131
# 787    6140
# 788    6150
# 789    6160
# 790    6161
# 791    6170
# 792    6180
# 793    6190
# 794    6210
# 795    6211
# 796    6230
# 797    6231
# 798    6240
# 799    6241
# 800    6250
# 801    6260
# 802    6270
# 803    6271
# 804    6280
# 805    6290
# 806    6291
# 807    6292
# 808    6300
# 809    6301
# 810    6310
# 811    6311
# 812    6312
# 813    6320
# 814    6331
# 815    6340
# 816    6350
# 817    6360
# 818    6370
# 819    6380
# 820    6381
# 821    6382
# 822    6390
# 823    6391
# 824    6400
# 825    6410
# 826    6430
# 827    6440
# 828    6450
# 829    6451
# 830    6460
# 831    6480
# 832    6490
# 833    6500
# 834    6510
# 835    6520
# 836    6521
# 837    6530
# 838    6531
# 839    6540
# 840    6541
# 841    6550
# 842    6560
# 843    6570
# 844    6580
# 845    6590
# 846    6600
# 847    6610
# 848    6611
# 849    6620
# 850    6630
# 851    6631
# 852    6650
# 853    6660
# 854    6661
# 855    6670
# 856    6680
# 857    6690
# 858    6700
# 859    6701
# 860    6720
# 861    6730
# 862    6740
# 863    6750
# 864    6760
# 865    6770
# 866    6780
# 867    6790
# 868    6791
# 869    6800
# 870    6810
# 871    6811
# 872    6820
# 873    6830
# 874    6840
# 875    6850
# 876    6860
# 877    6870
# 878    6871
# 879    6880
# 880    6881
# 881    6890
# 882    6900
# 883    6910
# 884    6920
# 885    6930
# 886    6940
# 887    6950
# 888    6951
# 889    6960
# 890    6970
# 891    6971
# 892    6990
# 893    7000
# 894    7001
# 895    7010
# 896    7011
# 897    7020
# 898    7030
# 899    7031
# 900    7040
# 901    7041
# 902    7050
# 903    7051
# 904    7060
# 905    7061
# 906    7070
# 907    7080
# 908    7090
# 909    7091
# 910    7100
# 911    7101
# 912    7110
# 913    7111
# 914    7140
# 915    7150
# 916    7160
# 917    7170
# 918    7180
# 919    7190
# 920    7200
# 921    7201
# 922    7202
# 923    7210
# 924    7220
# 925    7221
# 926    7222
# 927    7230
# 928    7240
# 929    7250
# 930    7260
# 931    7261
# 932    7270
# 933    7272
# 934    7280
# 935    7290
# 936    7300
# 937    7310
# 938    7320
# 939    7330
# 940    7340
# 941    7350
# 942    7351
# 943    7360
# 944    7361
# 945    7370
# 946    7380
# 947    7381
# 948    7390
# 949    7400
# 950    7410
# 951    7411
# 952    7420
# 953    7430
# 954    7431
# 955    7440
# 956    7441
# 957    7460
# 958    7461
# 959    7470
# 960    7480
# 961    7490
# 962    7491
# 963    7500
# 964    7501
# 965    7502
# 966    7510
# 967    7520
# 968    7521
# 969    7530
# 970    7540
# 971    7541
# 972    7550
# 973    7560
# 974    7570
# 975    7571
# 976    7580
# 977    7590
# 978    7600
# 979    7610
# 980    7620
# 981    7621
# 982    7630
# 983    7640
# 984    7660
# 985    7670
# 986    7680
# 987    7690
# 988    7702
# 989    7710
# 990    7720
# 991    7730
# 992    7740
# 993    7750
# 994    7760
# 995    7770
# 996    7780
# 997    7790
# 998    7800
# 999    7810
# 1000   7820
# 1001   7821
# 1002   7830
# 1003   7831
# 1004   7841
# 1005   7850
# 1006   7860
# 1007   7870
# 1008   7880
# 1009   7881
# 1010   7890
# 1011   7891
# 1012   7892
# 1013   7900
# 1014   7901
# 1015   7910
# 1016   7920
# 1017   7930
# 1018   7931
# 1019   7940
# 1020   7950
# 1021   7951
# 1022   7960
# 1023   7961
# 1024   7971
# 1025   7980
# 1026   7990
# 1027   8000
# 1028   8010
# 1029   8020
# 1030   8030
# 1031   8040
# 1032   8050
# 1033   8060
# 1034   8061
# 1035   8070
# 1036   8080
# 1037   8081
# 1038   8090
# 1039   8100
# 1040   8110
# 1041   8111
# 1042   8112
# 1043   8120
# 1044   8130
# 1045   8131
# 1046   8150
# 1047   8160
# 1048   8170
# 1049   8180
# 1050   8190
# 1051   8191
# 1052   8200
# 1053   8210
# 1054   8220
# 1055   8230
# 1056   8240
# 1057   8250
# 1058   8270
# 1059   8280
# 1060   8290
# 1061   8300
# 1062   8301
# 1063   8311
# 1064   8320
# 1065   8330
# 1066   8331
# 1067   8340
# 1068   8341
# 1069   8342
# 1070   8360
# 1071   8361
# 1072   8371
# 1073   8380
# 1074   8390
# 1075   8391
# 1076   8400
# 1077   8401
# 1078   8410
# 1079   8420
# 1080   8430
# 1081   8431
# 1082   8450
# 1083   8460
# 1084   8470
# 1085   8480
# 1086   8490
# 1087   8500
# 1088   8501
# 1089   8502
# 1090   8510
# 1091   8520
# 1092   8531
# 1093   8540
# 1094   8541
# 1095   8550
# 1096   8551
# 1097   8560
# 1098   8561
# 1099   8570
# 1100   8580
# 1101   8581
# 1102   8582
# 1103   8590
# 1104   8600
# 1105   8610
# 1106   8620
# 1107   8630
# 1108   8631
# 1109   8632
# 1110   8640
# 1111   8650
# 1112   8660
# 1113   8662
# 1114   8670
# 1115   8671
# 1116   8680
# 1117   8690
# 1118   8691
# 1119   8700
# 1120   8701
# 1121   8710
# 1122   8711
# 1123   8720
# 1124   8730
# 1125   8731
# 1126   8741
# 1127   8742
# 1128   8750
# 1129   8760
# 1130   8770
# 1131   8780
# 1132   8790
# 1133   8800
# 1134   8810
# 1135   8820
# 1136   8830
# 1137   8840
# 1138   8841
# 1139   8850
# 1140   8851
# 1141   8852
# 1142   8860
# 1143   8861
# 1144   8870
# 1145   8880
# 1146   8890
# 1147   8900
# 1148   8901
# 1149   8902
# 1150   8910
# 1151   8911
# 1152   8920
# 1153   8930
# 1154   8940
# 1155   8950
# 1156   8960
# 1157   8961
# 1158   8970
# 1159   8980
# 1160   8990
# 1161   8991
# 1162   9000
# 1163   9010
# 1164   9020
# 1165   9030
# 1166   9040
# 1167   9050
# 1168   9060
# 1169   9070
# 1170   9081
# 1171   9100
# 1172   9110
# 1173   9130
# 1174   9131
# 1175   9132
# 1176   9140
# 1177   9150
# 1178   9160
# 1179   9170
# 1180   9180
# 1181   9190
# 1182   9191
# 1183   9200
# 1184   9210
# 1185   9220
# 1186   9230
# 1187   9240
# 1188   9250
# 1189   9260
# 1190   9261
# 1191   9270
# 1192   9280
# 1193   9290
# 1194   9291
# 1195   9300
# 1196   9310
# 1197   9320
# 1198   9321
# 1199   9330
# 1200   9340
# 1201   9350
# 1202   9351
# 1203   9360
# 1204   9370
# 1205   9380
# 1206   9390
# 1207   9391
# 1208   9400
# 1209   9401
# 1210   9410
# 1211   9420
# 1212   9430
# 1213   9440
# 1214   9450
# 1215   9451
# 1216   9460
# 1217   9461
# 1218   9470
# 1219   9471
# 1220   9490
# 1221   9491
# 1222   9500
# 1223   9502
# 1224   9520
# 1225   9521
# 1226   9522
# 1227   9530
# 1228   9531
# 1229   9540
# 1230   9550
# 1231   9551
# 1232   9560
# 1233   9570
# 1234   9580
# 1235   9590
# 1236   9600
# 1237   9610
# 1238   9611
# 1239   9620
# 1240   9621
# 1241   9630
# 1242   9640
# 1243   9650
# 1244   9651
# 1245   9660
# 1246   9680
# 1247   9690
# 1248   9700
# 1249   9701
# 1250   9710
# 1251   9711
# 1252   9720
# 1253   9730
# 1254   9740
# 1255   9750
# 1256   9760
# 1257   9770
# 1258   9780
# 1259   9790
# 1260   9800
# 1261   9801
# 1262   9810
# 1263   9811
# 1264   9820
# 1265   9821
# 1266   9830
# 1267   9840
# 1268   9841
# 1269   9850
# 1270   9860
# 1271   9861
# 1272   9870
# 1273   9880
# 1274   9890
# 1275   9900
# 1276   9910
# 1277   9912
# 1278   9920
# 1279   9921
# 1280   9930
# 1281   9940
# 1282   9950
# 1283   9960
# 1284   9970
# 1285   9980
# 1286   9981
# 1287   9990
# 1288   9991
# 1289  10000
#
#                                                                                                                                                      Review  \
# 0                                                                                                                                        Loved this place .
# 1                                                                                                                                       Crust is not good .
# 2                                                                                                                              the texture was just nasty .
# 3                                                                                 Stopped by during the late May bank holiday off Rick Steve recommendation
# 4                                                                                                                       The selection on the menu was great
# 5                                                                                                                                    Now I am getting angry
# 6                                                                                                                                      I want my damn pho .
# 7                                                                                                                  Honeslty it did n't taste THAT fresh . )
# 8                                                                                                                             The potatoes were like rubber
# 9                                                                            you could tell they had been made up ahead of time being kept under a warmer .
# 10                                                                                                                               The fries were great too .
# 11                                                                                                                                          A great touch .
# 12                                                                                                                                Service was very prompt .
# 13                                                                                                                                      Would not go back .
# 14                                                     The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced .
# 15                                                                                        I tried the Cape Cod ravoli , chicken , with cranberry ... mmmm !
# 16                                                                                          I was disgusted because I was pretty sure that was human hair .
# 17                                                                                                      I was shocked because no signs indicate cash only .
# 18                                                                                                                                     Highly recommended .
# 19                                                                                                                  Waitress was a little slow in service .
# 20                                                                                                    This place is not worth your time , let alone Vegas .
# 21                                                                                                                                     The Burrittos Blah !
# 22                                                                                                                                     The food , amazing .
# 23                                                                                                                                   Service is also cute .
# 24                                                                                                                                    I could care less ...
# 25                                                                                                                         The interior is just beautiful .
# 26                                                                                That 's right .... the red velvet cake ..... ohhh this stuff is so good .
# 27                                                                                                              - They never brought a salad we asked for .
# 28                                                                                                   This hole in the wall has great Mexican street tacos ,
# 29                                                                                                                                         friendly staff .
# 30          Took an hour to get our food only 4 tables in restaurant my food was Luke warm , Our sever was running around like he was totally overwhelmed .
# 31                                                                                                                       The worst was the salmon sashimi .
# 32                                                                                                            Also there are combos like a burger , fries ,
# 33                                                                                                                     beer for 23 which is a decent deal .
# 34                                                                                                                           This was like the final blow !
# 35                                                                                                                           I found this place by accident
# 36                                                                                                                                 I could not be happier .
# 37                                                                                 seems like a good quick place to grab a bite of some familiar pub food ,
# 38                                                                                                                                         look elsewhere .
# 39                                                                                                                      Overall , I like this place a lot .
# 40                                                                          The only redeeming quality of the restaurant was that it was very inexpensive .
# 41                                                                                                                                           Ample portions
# 42                                                                                                                                            good prices .
# 43                                                               Poor service , the waiter made me feel like I was stupid every time he came to the table .
# 44                                                                                                                   My first visit to Hiro was a delight !
# 45                                                                                                                                          Service sucks .
# 46                                                                                                                                        The shrimp tender
# 47                                                                       There is not a deal good enough that would drag me into that establishment again .
# 48                                                          Hard to judge whether these sides were good because we were grossed out by the melted styrofoam
# 49                                                                                                        did n't want to eat it for fear of getting sick .
# 50                                                                                                       On a positive note , our server was very attentive
# 51                                                                                                                                 provided great service .
# 52                                                                            Frozen pucks of disgust , with some of the worst people behind the register .
# 53                                                                                                              The only thing I did like was the prime rib
# 54                                                                                                                                        dessert section .
# 55                                                                                                              It 's too bad the food is so damn generic .
# 56                                                                                                            The burger is good beef , cooked just right .
# 57                                                                                                        If you want a sandwich just go to any Firehouse !
# 58                                                                                               My side Greek salad with the Greek dressing was so tasty ,
# 59                                                                                                                             hummus was very refreshing .
# 60                                                                                                                                 We ordered the duck rare
# 61                                                                                                   tender on the inside with a nice char on the outside .
# 62                                                              He came running after us when he realized my husband had left his sunglasses on the table .
# 63                                                                                                                             Their chow mein is so good !
# 64                                                                                                         They have horrible attitudes towards customers ,
# 65                                                                                           talk down to each one when customers do n't enjoy their food .
# 66                                                                                                                                   The portion was huge !
# 67                                                                                                   Loved it ... friendly servers , great food , wonderful
# 68                                                                                                                                       imaginative menu .
# 69                                                         The Heart Attack Grill in downtown Vegas is an absolutely flat - lined excuse for a restaurant .
# 70                                                                                                                                         Not much seafood
# 71                                                                                                                  like 5 strings of pasta at the bottom .
# 72                                                The salad had just the right amount of sauce to not over power the scallop , which was perfectly cooked .
# 73                                                                                                                  The ripped banana was not only ripped ,
# 74                                                                    At least think to refill my water before I struggle to wave you over for 10 minutes .
# 75                                                                                                         This place receives stars for their APPETIZERS !
# 76                                                                                                                           The cocktails are all handmade
# 77                                                                                                                    We 'd definitely go back here again .
# 78                                                                                                                     We are so glad we found this place .
# 79                                                                                                                                               Great food
# 80                                                                                                                                  service , huge portions
# 81                                                                                                                          they give a military discount .
# 82                                                                                                                     Always a great time at Dos Gringos !
# 83                                                                                                                 Update ..... went back for a second time
# 84                                                                                                                             it was still just as amazing
# 85                                                                                                                                          We got the food
# 86                                                                                                                 apparently they have never heard of salt
# 87                                                                                                                       the batter on the fish was chewy .
# 88                                                                                                                          A great way to finish a great .
# 89                                                                                                                             The deal included 5 tastings
# 90                                                                                                                                          Jeff went above
# 91                                                                                                                                beyond what we expected .
# 92                                                                                                             - Really , really good rice , all the time .
# 93                                                                                                                                    The service was meh .
# 94                                                                It took over 30 min to get their milkshake , which was nothing more than chocolate milk .
# 95                                                         I guess I should have known that this place would suck , because it is inside of the Excalibur ,
# 96                                                                                                                          I did n't use my common sense .
# 97                                                                                                  The scallop dish is quite appalling for value as well .
# 98                                                                                                                    2 times - Very Bad Customer Service !
# 99                                                                                                                    The sweet potato fries were very good
# 100                                                                                                                                         seasoned well .
# 101                                                                                               Today is the second time I 've been to their lunch buffet
# 102                                                                                                                                    it was pretty good .
# 103                                              There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice
# 104                 Coming here is like experiencing an underwhelming relationship where both parties ca n't wait for the other person to ask to break up .
# 105                                                                                                               the place smelled like an old grease trap
# 106                                                                                                                            only 2 others there eating .
# 107                                                                                                                                 roast beef were bland .
# 108                                         The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old .
# 109                                                                                                                                          I love the Pho
# 110                                                                                                          the spring rolls oh so yummy you have to try .
# 111                                                                              The poor batter to meat ratio made the chicken tenders very unsatisfying .
# 112                                                                                                             All I have to say is the food was amazing !
# 113                                                                                                                                Omelets are to die for !
# 114                                                                                                                                    Everything was fresh
# 115                                                                                       In summary , this was a largely disappointing dining experience .
# 116                               It 's like a really sexy party in your mouth , where you 're outrageously flirting with the hottest person at the party .
# 117                                                                      Never been to Hard Rock Casino before , WILL NEVER EVER STEP FORWARD IN IT AGAIN !
# 118                                                                                                                                 Best breakfast buffet !
# 119                                                                                                                          say bye bye to your tip lady !
# 120                                                                                                                                  Food arrived quickly !
# 121                                                                                                   On the up side , their cafe serves really good food .
# 122                                                                                                                                Our server was fantastic
# 123                                                                                                         when he found out the wife loves roasted garlic
# 124                                                                                                                bone marrow , he added extra to our meal
# 125                                                                                                                                  another marrow to go !
# 126                                                                                                The only good thing was our waiter , he was very helpful
# 127                                                                                                                        kept the bloddy mary 's coming .
# 128                                                                                               Best Buffet in town , for the price you can not beat it .
# 129                                                                             I LOVED their mussels cooked in this wine reduction , the duck was tender ,
# 130                                                                                                                    their potato dishes were delicious .
# 131                                                                                                 This is one of the better buffets that I have been to .
# 132                                                                                                                                So we went to Tigerlilly
# 133                                                                                                                             had a fantastic afternoon !
# 134                                                                                                    The food was delicious , our bartender was attentive
# 135                                                                                                                                   we got a great deal !
# 136                                                                                                                               The ambience is wonderful
# 137                                                                                                                                there is music playing .
# 138                                                                                                                            Will go back next trip out .
# 139                                                                                                                                           Sooooo good !
# 140                                                                                          REAL sushi lovers , let 's be honest - Yama is not that good .
# 141                                                                                                            At least 40min passed in between us ordering
# 142                                                                                                                                     the food arriving ,
# 143                                                                          This is a really fantastic Thai restaurant which is definitely worth a visit .
# 144                                                                                                                                            Nice , spicy
# 145                                                                                                                                           Good prices .
# 146                                                                                                                                   It was pretty gross !
# 147                                                                                                                           I 've had better atmosphere .
# 148                                                                                                                         Kind of hard to mess up a steak
# 149                                                                                                                     Although I very much liked the look
# 150                                                                                   sound of this place , the actual experience was a bit disappointing .
# 151                        I just do n't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine .
# 152                                                                                                                                 Worst service to boot ,
# 153                                                                                                                    that is the least of their worries .
# 154                                                                                                                                        Service was fine
# 155                                                                                                                             the waitress was friendly .
# 156                                                                                                                               The guys all had steaks ,
# 157                                                                                                      our steak loving son who has had steak at the best
# 158                                                                                              worst places said it was the best steak he 's ever eaten .
# 159                                                                                      We thought you 'd have to venture further away to get good sushi ,
# 160                                                                                                             this place really hit the spot that night .
# 161                                                                                                 Host staff were , for lack of a better word , BITCHES !
# 162                                                                                               Bland ... Not a liking this place for a number of reasons
# 163                                                                                                         I do n't want to waste time on bad reviewing ..
# 164                                                                                                                               Phenomenal food , service
# 165                                                                                                                                    I would n't return .
# 166                                                     Definitely worth venturing off the strip for the pork belly , will return next time I 'm in Vegas .
# 167                                                                                                    This place is way too overpriced for mediocre food .
# 168                                                                                                                                 Penne vodka excellent !
# 169                                   They have a good selection of food including a massive meatloaf sandwich , a crispy chicken wrap , a delish tuna melt
# 170                                                                                                                                    some tasty burgers .
# 171                                                                                                                                The management is rude .
# 172                                                                    Delicious NYC bagels , good selections of cream cheese , real Lox with capers even .
# 173                                            Great Subway , in fact it 's so good when you come here every other Subway will not meet your expectations .
# 174                                                                                                                I had a seriously solid breakfast here .
# 175                                                                                                       This is one of the best bars with food in Vegas .
# 176                                                                                                                                   He was extremely rude
# 177                                                        really , there are so many other restaurants I would love to dine at during a weekend in Vegas .
# 178                                                                                                                                My drink was never empty
# ...
# 1048            food              FOOD#QUALITY         negative
# 1049           fruit              FOOD#QUALITY         positive
# 1050                              FOOD#QUALITY         positive
# 1051                              FOOD#QUALITY         negative
# 1052           place        RESTAURANT#GENERAL         positive
# 1053                              FOOD#QUALITY         positive
# 1054           money              FOOD#QUALITY         negative
# 1055           boxes              FOOD#QUALITY         positive
# 1056           crêpe              FOOD#QUALITY         positive
# 1057         service           SERVICE#GENERAL         negative
# 1058         quality              FOOD#QUALITY         negative
# 1059           place        RESTAURANT#GENERAL         positive
# 1060         service           SERVICE#GENERAL         positive
# 1061           sushi              FOOD#QUALITY         positive
# 1062             hip              FOOD#QUALITY         positive
# 1063            dish              FOOD#QUALITY         positive
# 1064         service           SERVICE#GENERAL         negative
# 1065            food              FOOD#QUALITY         negative
# 1066            wait           SERVICE#GENERAL         negative
# 1067         service           SERVICE#GENERAL         positive
# 1068          server           SERVICE#GENERAL         positive
# 1069             day              FOOD#QUALITY         positive
# 1070            bill              FOOD#QUALITY         positive
# 1071          server           SERVICE#GENERAL         positive
# 1072      experience              FOOD#QUALITY         positive
# 1073          spices              FOOD#QUALITY         negative
# 1074            Food              FOOD#QUALITY         negative
# 1075        portions        FOOD#STYLE_OPTIONS         negative
# 1076                              FOOD#QUALITY         positive
# 1077            week              FOOD#QUALITY         positive
# 1078            food              FOOD#QUALITY         negative
# 1079            food              FOOD#QUALITY         positive
# 1080           visit              FOOD#QUALITY         positive
# 1081           salad              FOOD#QUALITY         positive
# 1082         oysters              FOOD#QUALITY         positive
# 1083           place        RESTAURANT#GENERAL         positive
# 1084           place        RESTAURANT#GENERAL         positive
# 1085           stars              FOOD#QUALITY         positive
# 1086            dish              FOOD#QUALITY         negative
# 1087             day              FOOD#QUALITY         negative
# 1088             job              FOOD#QUALITY         negative
# 1089          dishes              FOOD#QUALITY         positive
# 1090        potatoes              FOOD#QUALITY         positive
# 1091                              FOOD#QUALITY         negative
# 1092            heat              FOOD#QUALITY         positive
# 1093           price              FOOD#QUALITY         positive
# 1094         service           SERVICE#GENERAL         positive
# 1095          shrimp              FOOD#QUALITY         positive
# 1096         friends              FOOD#QUALITY         positive
# 1097           fella              FOOD#QUALITY         positive
# 1098                              FOOD#QUALITY         positive
# 1099           wines            DRINKS#QUALITY         positive
# 1100          buffet              FOOD#QUALITY         negative
# 1101                              FOOD#QUALITY         negative
# 1102             lot              FOOD#QUALITY         positive
# 1103                              FOOD#QUALITY         negative
# 1104           while              FOOD#QUALITY         negative
# 1105           place        RESTAURANT#GENERAL         positive
# 1106          course              FOOD#QUALITY         positive
# 1107          dishes              FOOD#QUALITY         positive
# 1108           staff           SERVICE#GENERAL         positive
# 1109             oil              FOOD#QUALITY         positive
# 1110           fries              FOOD#QUALITY         positive
# 1111        pleasure              FOOD#QUALITY         negative
# 1112          salads              FOOD#QUALITY         positive
# 1113        approval              FOOD#QUALITY         negative
# 1114           place        RESTAURANT#GENERAL         positive
# 1115          summer              FOOD#QUALITY         positive
# 1116           place        RESTAURANT#GENERAL         positive
# 1117         manager           SERVICE#GENERAL         positive
# 1118           table              FOOD#QUALITY         positive
# 1119            feel          AMBIENCE#GENERAL         positive
# 1120         service           SERVICE#GENERAL         negative
# 1121           stars              FOOD#QUALITY         positive
# 1122                              FOOD#QUALITY         negative
# 1123           sushi              FOOD#QUALITY         negative
# 1124            menu        FOOD#STYLE_OPTIONS         positive
# 1125         setting          AMBIENCE#GENERAL         positive
# 1126             bar          AMBIENCE#GENERAL         positive
# 1127      experience              FOOD#QUALITY         positive
# 1128          owners              FOOD#QUALITY         positive
# 1129            meat              FOOD#QUALITY         positive
# 1130           store              FOOD#QUALITY         positive
# 1131                              FOOD#QUALITY         positive
# 1132            dude              FOOD#QUALITY         positive
# 1133           pizza              FOOD#QUALITY         positive
# 1134           salsa              FOOD#QUALITY         negative
# 1135            food              FOOD#QUALITY         negative
# 1136                              FOOD#QUALITY         positive
# 1137            soup              FOOD#QUALITY         negative
# 1138       meatballs              FOOD#QUALITY         negative
# 1139       occasions              FOOD#QUALITY         positive
# 1140                              FOOD#QUALITY         negative
# 1141           plate              FOOD#QUALITY         negative
# 1142           bites              FOOD#QUALITY         positive
# 1143                              FOOD#QUALITY         positive
# 1144         service           SERVICE#GENERAL         negative
# 1145           table              FOOD#QUALITY         positive
# 1146           latte              FOOD#QUALITY         positive
# 1147            menu        FOOD#STYLE_OPTIONS         positive
# 1148        waitress           SERVICE#GENERAL         positive
# 1149         peanuts              FOOD#QUALITY         negative
# 1150       boyfriend              FOOD#QUALITY         positive
# 1151            love              FOOD#QUALITY         positive
# 1152           beers      DRINKS#STYLE_OPTIONS         positive
# 1153         Pricing              FOOD#QUALITY         negative
# 1154                              FOOD#QUALITY         negative
# 1155       breakfast              FOOD#QUALITY         negative
# 1156          server           SERVICE#GENERAL         positive
# 1157         service           SERVICE#GENERAL         positive
# 1158      selections              FOOD#QUALITY         positive
# 1159             tea              FOOD#QUALITY         positive
# 1160                              FOOD#QUALITY         positive
# 1161          patron              FOOD#QUALITY         negative
# 1162      experience              FOOD#QUALITY         positive
# 1163           money              FOOD#QUALITY         positive
# 1164           bread              FOOD#QUALITY         positive
# 1165                              FOOD#QUALITY         positive
# 1166          drinks            DRINKS#QUALITY         positive
# 1167           order              FOOD#QUALITY         positive
# 1168           house              FOOD#QUALITY         positive
# 1169         dessert              FOOD#QUALITY         negative
# 1170            sals              FOOD#QUALITY         positive
# 1171            spot  RESTAURANT#MISCELLANEOUS         positive
# 1172        chickens              FOOD#QUALITY         positive
# 1173                              FOOD#QUALITY         positive
# 1174                              FOOD#QUALITY         negative
# 1175           being              FOOD#QUALITY         positive
# 1176           steak              FOOD#QUALITY         positive
# 1177         concept              FOOD#QUALITY         negative
# 1178           thing              FOOD#QUALITY         negative
# 1179      experience              FOOD#QUALITY         positive
# 1180          buffet              FOOD#QUALITY         positive
# 1181           fries              FOOD#QUALITY         positive
# 1182             yay              FOOD#QUALITY         positive
# 1183            trip              FOOD#QUALITY         positive
# 1184                              FOOD#QUALITY         positive
# 1185           place        RESTAURANT#GENERAL         negative
# 1186          degree              FOOD#QUALITY         positive
# 1187        calamari              FOOD#QUALITY         positive
# 1188          fondue              FOOD#QUALITY         positive
# 1189            meal              FOOD#QUALITY         positive
# 1190           lunch              FOOD#QUALITY         positive
# 1191           heart              FOOD#QUALITY         negative
# 1192           check              FOOD#QUALITY         negative
# 1193     restaurants              FOOD#QUALITY         positive
# 1194             one              FOOD#QUALITY         positive
# 1195      experience              FOOD#QUALITY         negative
# 1196            food              FOOD#QUALITY         positive
# 1197            food              FOOD#QUALITY         positive
# 1198           place        RESTAURANT#GENERAL         negative
# 1199                              FOOD#QUALITY         negative
# 1200                              FOOD#QUALITY         positive
# 1201           place        RESTAURANT#GENERAL         positive
# 1202            food              FOOD#QUALITY         negative
# 1203           place        RESTAURANT#GENERAL         positive
# 1204         sangria              FOOD#QUALITY         positive
# 1205                              FOOD#QUALITY         negative
# 1206            meat              FOOD#QUALITY         negative
# 1207            pork              FOOD#QUALITY         positive
# 1208        bathroom          AMBIENCE#GENERAL         positive
# 1209                              FOOD#QUALITY         positive
# 1210                              FOOD#QUALITY         negative
# 1211           hurry              FOOD#QUALITY         negative
# 1212     reservation              FOOD#QUALITY         negative
# 1213     imagination              FOOD#QUALITY         positive
# 1214           sauce              FOOD#QUALITY         negative
# 1215      vegetables              FOOD#QUALITY         positive
# 1216           sause              FOOD#QUALITY         negative
# 1217            heat              FOOD#QUALITY         negative
# 1218             bit              FOOD#QUALITY         positive
# 1219          flavor              FOOD#QUALITY         negative
# 1220           place        RESTAURANT#GENERAL         negative
# 1221             way              FOOD#QUALITY         negative
# 1222            fare              FOOD#QUALITY         positive
# 1223                              FOOD#QUALITY         negative
# 1224          tables          AMBIENCE#GENERAL         positive
# 1225         workers              FOOD#QUALITY         positive
# 1226            menu        FOOD#STYLE_OPTIONS         positive
# 1227        ambiance          AMBIENCE#GENERAL         positive
# 1228             tea              FOOD#QUALITY         positive
# 1229         service           SERVICE#GENERAL         positive
# 1230           fries              FOOD#QUALITY         positive
# 1231          burger              FOOD#QUALITY         negative
# 1232                              FOOD#QUALITY         negative
# 1233  disappointment              FOOD#QUALITY         negative
# 1234  disappointment              FOOD#QUALITY         negative
# 1235         husband              FOOD#QUALITY         negative
# 1236          reason              FOOD#QUALITY         positive
# 1237   deuchebaggery              FOOD#QUALITY         negative
# 1238           break              FOOD#QUALITY         positive
# 1239         service           SERVICE#GENERAL         negative
# 1240            cart           SERVICE#GENERAL         positive
# 1241           blame              FOOD#QUALITY         negative
# 1242  disappointment              FOOD#QUALITY         negative
# 1243                              FOOD#QUALITY         positive
# 1244                              FOOD#QUALITY         negative
# 1245       hamburger              FOOD#QUALITY         negative
# 1246                              FOOD#QUALITY         negative
# 1247      restaurant        RESTAURANT#GENERAL         positive
# 1248            deal        FOOD#STYLE_OPTIONS         positive
# 1249                              FOOD#QUALITY         negative
# 1250         manager           SERVICE#GENERAL         negative
# 1251             bar          AMBIENCE#GENERAL         positive
# 1252        ambiance          AMBIENCE#GENERAL         negative
# 1253         entrees              FOOD#QUALITY         positive
# 1254            food              FOOD#QUALITY         positive
# 1255          server           SERVICE#GENERAL         positive
# 1256                              FOOD#QUALITY         positive
# 1257           place        RESTAURANT#GENERAL         positive
# 1258                              FOOD#QUALITY         negative
# 1259           lunch              FOOD#QUALITY         positive
# 1260            time              FOOD#QUALITY         positive
# 1261            food              FOOD#QUALITY         positive
# 1262   circumstances              FOOD#QUALITY         positive
# 1263            list              FOOD#QUALITY         positive
# 1264           color              FOOD#QUALITY         positive
# 1265                              FOOD#QUALITY         positive
# 1266            Food              FOOD#QUALITY         negative
# 1267          movies              FOOD#QUALITY         positive
# 1268      restaurant        RESTAURANT#GENERAL         negative
# 1269            flop              FOOD#QUALITY         negative
# 1270         problem              FOOD#QUALITY         negative
# 1271      vegetables              FOOD#QUALITY         positive
# 1272             ice              FOOD#QUALITY         positive
# 1273          flavor              FOOD#QUALITY         negative
# 1274           place        RESTAURANT#GENERAL         positive
# 1275           place        RESTAURANT#GENERAL         negative
# 1276            meal              FOOD#QUALITY         positive
# 1277            food              FOOD#QUALITY         negative
# 1278           money              FOOD#QUALITY         positive
# 1279           place        RESTAURANT#GENERAL         positive
# 1280            lady              FOOD#QUALITY         positive
# 1281    presentation              FOOD#QUALITY         negative
# 1282                              FOOD#QUALITY         negative
# 1283            food              FOOD#QUALITY         negative
# 1284                              FOOD#QUALITY         positive
# 1285                              FOOD#QUALITY         negative
# 1286                              FOOD#QUALITY         negative
# 1287      experience              FOOD#QUALITY         positive
# 1288            time              FOOD#QUALITY         positive
# 1289           check              FOOD#QUALITY         positive

# %% [markdown]
# # Charts

# %%
import matplotlib.pyplot as plt
# Group the DataFrame by 'Opinion_Category' and 'Opinion_Polarity' and count occurrences
grouped = df.groupby(['Opinion_Category', 'Opinion_Polarity']).size().unstack(fill_value=0)

# Calculate the percentage of positive Opinion_Polarity for each Opinion_Category
grouped['Percentage of Positive Opinion_Polarity'] = (grouped['positive'] / (grouped['positive'] + grouped['negative'])) * 100

# Plot the percentage of positive Opinion_Polarity for each Opinion_Category
ax = grouped['Percentage of Positive Opinion_Polarity'].plot(kind='bar', color='skyblue')
ax.set_xlabel('Opinion_Category')
ax.set_ylabel('Percentage of Positive Opinion_Polarity')
plt.title('Percentage of Positive Opinion_Polarity by Opinion_Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('output/images/sample_plot.jpg')
plt.show()

# %%
# Group the DataFrame by 'Opinion_Category' and 'Opinion_Polarity' and count occurrences
grouped = df.groupby(['Opinion_Category', 'Opinion_Polarity']).size().unstack(fill_value=0)

# Calculate the percentage of positive Opinion_Polarity for each Opinion_Category
grouped['Percentage of Negative Opinion_Polarity'] = (grouped['negative'] / (grouped['positive'] + grouped['negative'])) * 100

# Plot the percentage of positive Opinion_Polarity for each Opinion_Category
ax = grouped['Percentage of Negative Opinion_Polarity'].plot(kind='bar', color='skyblue')
ax.set_xlabel('Opinion_Category')
ax.set_ylabel('Percentage of Negative Opinion_Polarity')
plt.title('Percentage of Negative Opinion_Polarity by Opinion_Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('output/images/sample_plot1.jpg')
plt.show()

# %%
# Group the DataFrame by 'Opinion_Category' and 'Opinion_Polarity' and count occurrences
grouped = df.groupby(['Opinion_Category', 'Opinion_Polarity']).size().unstack(fill_value=0)

# Calculate the percentage of positive and negative Opinion_Polarity for each Opinion_Category
grouped['Percentage of Positive Opinion_Polarity'] = (grouped['positive'] / (grouped['positive'] + grouped['negative'])) * 100
grouped['Percentage of Negative Opinion_Polarity'] = (grouped['negative'] / (grouped['positive'] + grouped['negative'])) * 100

# Plot the percentages of positive and negative Opinion_Polarity for each Opinion_Category
ax = grouped[['Percentage of Positive Opinion_Polarity', 'Percentage of Negative Opinion_Polarity']].plot(kind='bar', color=['skyblue', 'salmon'])
ax.set_xlabel('Opinion_Category')
ax.set_ylabel('Percentage')
plt.title('Percentage of Positive and Negative Opinion_Polarity by Opinion_Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('output/images/sample_plot2.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the DataFrame by 'Opinion_Category' and 'Opinion_Polarity' and count occurrences
grouped = df.groupby(['Opinion_Category', 'Opinion_Polarity']).size().unstack(fill_value=0)

# Calculate the percentage of positive and negative Opinion_Polarity for each Opinion_Category
grouped['Percentage of Positive Opinion_Polarity'] = (grouped['positive'] / (grouped['positive'] + grouped['negative'])) * 100
grouped['Percentage of Negative Opinion_Polarity'] = (grouped['negative'] / (grouped['positive'] + grouped['negative'])) * 100

# Plot a stacked bar chart for the percentages
ax = grouped[['Percentage of Positive Opinion_Polarity', 'Percentage of Negative Opinion_Polarity']].plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
ax.set_xlabel('Opinion_Category')
ax.set_ylabel('Percentage')
plt.title('Percentage of Positive and Negative Opinion_Polarity by Opinion_Category')
plt.xticks(rotation=45)
plt.tight_layout()

# Add a legend
plt.legend(title='Opinion_Polarity', labels=['Positive', 'Negative'])

# Save the chart as an image
plt.savefig('output/images/sample_stacked_bar_chart.jpg')

# Show the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group the DataFrame by 'Opinion_Category' and count occurrences
grouped = input_df['Opinion_Category'].value_counts().reset_index()
grouped.columns = ['Opinion_Category', 'Count']

# Calculate the percentage of total reviews for each category
grouped['Percentage of Total Reviews'] = (grouped['Count'] / grouped['Count'].sum()) * 100

# Set colors for the doughnut chart
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightcyan']

# Create a doughnut chart for Opinion_Category Distribution
fig, ax = plt.subplots()

# Plot the pie chart (outer circle)
wedges, texts, autotexts = ax.pie(
    grouped['Count'],
    labels=None,  # No labels on slices
    autopct='',
    startangle=140,
    colors=colors,
    wedgeprops=dict(width=0.4)  # Set the width to create a doughnut chart
)

# Add a legend with color-coded labels and percentages in a table
legend_labels = [f'{category}: {percentage:.1f}%' for category, percentage in zip(grouped['Opinion_Category'], grouped['Percentage of Total Reviews'])]
ax.legend(wedges, legend_labels, loc="center left", bbox_to_anchor=(1, 0.5), title="Opinion_Category")

plt.axis('equal')
plt.title('Opinion_Category Distribution (Doughnut Chart)')

plt.tight_layout()
plt.savefig('output/images/opinion_category_doughnut_chart.jpg')
plt.show()

# %%
# Group the DataFrame by 'Opinion_Category' and 'Opinion_Polarity' and count occurrences
grouped = df.groupby(['Opinion_Category', 'Opinion_Polarity']).size().unstack(fill_value=0)

# Calculate the percentage of positive and negative Opinion_Polarity for each Opinion_Category
grouped['Percentage of Positive Opinion_Polarity'] = (grouped['positive'] / (grouped['positive'] + grouped['negative'])) * 100
grouped['Percentage of Negative Opinion_Polarity'] = (grouped['negative'] / (grouped['positive'] + grouped['negative'])) * 100

# Group the DataFrame by 'Aspect' and count occurrences
grouped_aspect = input_df['Opinion_Category'].value_counts().reset_index()
grouped_aspect.columns = ['Opinion_Category', 'Count']

# Calculate the percentage of each Opinion_Category in the total reviews
grouped_aspect['Percentage of Total Reviews'] = (grouped_aspect['Count'] / grouped_aspect['Count'].sum()) * 100

# Create a summary table
summary_table = grouped.join(grouped_aspect.set_index('Opinion_Category'), on='Opinion_Category')
summary_table['Percentage of Total Reviews'] = summary_table['Percentage of Total Reviews'].fillna(0)

# Print the summary table
print(summary_table)

# Plot the percentages of positive and negative Opinion_Polarity for each Opinion_Category
ax = summary_table[['Percentage of Positive Opinion_Polarity', 'Percentage of Negative Opinion_Polarity']].plot(kind='bar', color=['skyblue', 'salmon'])
ax.set_xlabel('Opinion_Category')
ax.set_ylabel('Percentage')
plt.title('Percentage of Positive and Negative Opinion_Polarity by Opinion_Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('static/images/sample_plot2.jpg')

# Plot the pie chart for Opinion_Category Distribution
plt.figure(figsize=(6, 6))
plt.pie(grouped_aspect['Count'], labels=grouped_aspect['Opinion_Category'], autopct='%1.1f%%', startangle=220, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightcyan'])
plt.title('Opinion_Category Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig('output/images/sample_plot7.jpg')
plt.show()
# Out:
#                           negative  positive  \
# Opinion_Category
# AMBIENCE#GENERAL                54       147
# DRINKS#PRICES                    8        11
# DRINKS#QUALITY                   2        32
# DRINKS#STYLE_OPTIONS             2        25
# FOOD#GENERAL                     2         0
# FOOD#PRICES                     48        29
# FOOD#QUALITY                   276       427
# FOOD#STYLE_OPTIONS              52        60
# LOCATION#GENERAL                 4        17
# RESTAURANT#GENERAL              94       214
# RESTAURANT#MISCELLANEOUS        34        42
# RESTAURANT#PRICES               28        29
# SERVICE#GENERAL                200       161
#
#                           Percentage of Positive Opinion_Polarity  \
# Opinion_Category
# AMBIENCE#GENERAL                                        73.134328
# DRINKS#PRICES                                           57.894737
# DRINKS#QUALITY                                          94.117647
# DRINKS#STYLE_OPTIONS                                    92.592593
# FOOD#GENERAL                                             0.000000
# FOOD#PRICES                                             37.662338
# FOOD#QUALITY                                            60.739687
# FOOD#STYLE_OPTIONS                                      53.571429
# LOCATION#GENERAL                                        80.952381
# RESTAURANT#GENERAL                                      69.480519
# RESTAURANT#MISCELLANEOUS                                55.263158
# RESTAURANT#PRICES                                       50.877193
# SERVICE#GENERAL                                         44.598338
#
#                           Percentage of Negative Opinion_Polarity   Count  \
# Opinion_Category
# AMBIENCE#GENERAL                                        26.865672    36.0
# DRINKS#PRICES                                           42.105263     NaN
# DRINKS#QUALITY                                           5.882353     7.0
# DRINKS#STYLE_OPTIONS                                     7.407407     1.0
# FOOD#GENERAL                                           100.000000     NaN
# FOOD#PRICES                                             62.337662     NaN
# FOOD#QUALITY                                            39.260313  1011.0
# FOOD#STYLE_OPTIONS                                      46.428571    22.0
# LOCATION#GENERAL                                        19.047619     2.0
# RESTAURANT#GENERAL                                      30.519481    92.0
# RESTAURANT#MISCELLANEOUS                                44.736842     7.0
# RESTAURANT#PRICES                                       49.122807     NaN
# SERVICE#GENERAL                                         55.401662   112.0
#
#                           Percentage of Total Reviews
# Opinion_Category
# AMBIENCE#GENERAL                             2.790698
# DRINKS#PRICES                                0.000000
# DRINKS#QUALITY                               0.542636
# DRINKS#STYLE_OPTIONS                         0.077519
# FOOD#GENERAL                                 0.000000
# FOOD#PRICES                                  0.000000
# FOOD#QUALITY                                78.372093
# FOOD#STYLE_OPTIONS                           1.705426
# LOCATION#GENERAL                             0.155039
# RESTAURANT#GENERAL                           7.131783
# RESTAURANT#MISCELLANEOUS                     0.542636
# RESTAURANT#PRICES                            0.000000
# SERVICE#GENERAL                              8.682171

# %%
# Opinion_Polarity distribution in our dataset
# df.Opinion_Polarity.value_counts().sort_values().plot(kind = 'bar')
sns.countplot(x = "Opinion_Polarity", data = df)
plt.show()

# %% [markdown]
# ### --------------------------------XxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxX-------------------------------------

# %% [markdown]
# # Aspect and Sentiment analysis for a random text

# %% [markdown]
# ### Text

# %%
text = "The pizza is delicious but service is terrible. The atmosphere is also not good.😀"
text = '''I recently dined at this restaurant, and I must say the food was excellent. 
The steak was perfectly cooked and very flavorful. However, the service was unsatisfactory.
The waitstaff seemed disorganized, and our orders took longer than expected. Despite that,
the ambiance of the restaurant was lovely, and the dessert was a delightful ending to the meal. Overall, 
a mixed experience'''
# text = "बढ़िया खाना था😀"
# text = "food😀"

# %% [markdown]
# ### Breaking complex sentence into simple sentences

# %%
simplified_sentences = split_complex_sentence(preprocess_text(text,1))
simplified_sentences
# Out:
# ['I recently dined at this restaurant ,',
#  'I must say the food was excellent .',
#  'The steak was perfectly cooked',
#  'very flavorful .',
#  'However , the service was unsatisfactory .',
#  'The waitstaff seemed disorganized ,',
#  'our orders took longer than expected .',
#  'Despite tha t , the ambiance of the restaurant was lovely ,',
#  'the dessert was a delightful ending to the meal .',
#  'Overal l , a mixed experience']

# %% [markdown]
# ### Opinion Target(Aspect) Extraction

# %%
# An empty list for obtaining the extracted aspects from sentences.  
ext_aspects = [] 
aspects =[]

# Performing Aspect Extraction 
for sen in simplified_sentences: 
    important = nlp(sen)  # Fix the variable name 'sen'
    descriptive_item = '' 
    target = '' 
    for token in important: 
        if token.dep_ == 'nsubj' and token.pos_ == 'NOUN': 
            target = token.text
        elif token.pos_ == 'NOUN': 
            target = token.text
    if target == "": target = "restaurant"
    aspects.append(target)

print("\nASPECTS : ",aspects)
# Out:
# ASPECTS :  ['restaurant', 'food', 'steak', 'restaurant', 'service', 'waitstaff', 'orders', 'restaurant', 'meal', 'experience']

# %% [markdown]
# ### Predict the Opinion_Category

# %%
# Vectorize the sample sentence using the same tfidf_vectorizer
sample_tfidf = tfidf_vectorizer1.transform(aspects)

# Predict the sentiment for the sample sentence
predicted_aspect = SVM_opinion_category_classifier.predict(sample_tfidf)

print(f"Predicted Aspect Category: {predicted_aspect}")
# Out:
# Predicted Aspect Category: ['RESTAURANT#GENERAL' 'FOOD#QUALITY' 'FOOD#QUALITY' 'RESTAURANT#GENERAL'
#  'SERVICE#GENERAL' 'SERVICE#GENERAL' 'FOOD#QUALITY' 'RESTAURANT#GENERAL'
#  'FOOD#QUALITY' 'FOOD#QUALITY']

# %% [markdown]
# ### Predict the Opinion_Polarity

# %%
# Create a SentimentIntensityAnalyzer object
sid = SentimentIntensityAnalyzer()

# Preprocess the sample sentences
preprocessed_sample_sentences = [preprocess_text(sentence,1) for sentence in simplified_sentences]

predicted_sentiments = []
# Analyze sentiment
for sentence in preprocessed_sample_sentences:
    sentiment_scores = sid.polarity_scores(sentence)
    # Determine the sentiment label
    if sentiment_scores['compound'] >= 0.05:
        sentiment_label = "positive"
    elif sentiment_scores['compound'] <= -0.05:
        sentiment_label = "negative"
    else:
        sentiment_label = "neutral"

    predicted_sentiments.append(sentiment_label)
#     print(f"Text: {sentence}")
#     print(f"Compound Score: {sentiment_scores['compound']}")
print(f"Predicted Sentiment: {predicted_sentiments}")
# Out:
# Predicted Sentiment: ['neutral', 'positive', 'positive', 'neutral', 'neutral', 'negative', 'neutral', 'positive', 'positive', 'neutral']

# %% [markdown]
# ### Resultant Table:

# %%
Result_df = pd.DataFrame({"Aspect_Term" : aspects,
                          "Aspect_Category" : predicted_aspect,
                          "Sentiment" : predicted_sentiments})
Result_df
# Out:
#   Aspect_Term     Aspect_Category Sentiment
# 0  restaurant  RESTAURANT#GENERAL   neutral
# 1        food        FOOD#QUALITY  positive
# 2       steak        FOOD#QUALITY  positive
# 3  restaurant  RESTAURANT#GENERAL   neutral
# 4     service     SERVICE#GENERAL   neutral
# 5   waitstaff     SERVICE#GENERAL  negative
# 6      orders        FOOD#QUALITY   neutral
# 7  restaurant  RESTAURANT#GENERAL  positive
# 8        meal        FOOD#QUALITY  positive
# 9  experience        FOOD#QUALITY   neutral

# %%
# res = zip(aspects,predicted_aspect,predicted_sentiments)
# sa=[]
# for i,j,k in res:
#     sa.append(",".join([i,j,k]))
# st = "\n".join(sa)
# print(st)
